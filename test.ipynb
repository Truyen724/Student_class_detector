# %%
from cam import detect_faces,mask_detect
import cv2

# %%
img = cv2.imread("IMG_8964.JPG")
# img = mask_detect(img)
img = cv2.resize(img,(1080,720))
cv2.imshow('frame', img)
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.imwrite("im_1080_720.jpg", img)
# Out:
# True

# %%
img = cv2.imread("IMG_8964.JPG")
print(img.shape)
# Out:
# (3648, 5472, 3)

# %%
5472/3648
# Out:
# 1.5

# %%
print(5472/(1.5**4))
print(3648/(1.5**4))
# Out:
# 1080.888888888889
# 720.5925925925926

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('IMG_8964.JPG')
img = cv2.resize(img,(1080,720))
imgplot = plt.imshow(img)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
